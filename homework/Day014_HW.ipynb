# Movie: 末代皇帝, ID: 10640
# Movie: 奪命隧道, ID: 10599
# Movie: 陪你玩最大, ID: 10602
# Movie: 觸不到的愛, ID: 10598
# Movie: 壞教育, ID: 10617
# Movie: 美好拾光公司, ID: 10541
# Movie: 鑰命監獄, ID: 10579
# Movie: 謝謝你, ID: 10571
# Movie: 女聲我最美, ID: 10528
# Movie: 間諜速成班, ID: 10538
# Movie: 我的英雄學院劇場版：英雄新世紀, ID: 10481
# Movie: 魔髮精靈唱遊世界, ID: 10466
# Movie: 迷雁返家路, ID: 10533
# Movie: 最初的晚餐, ID: 10510
# Movie: 刺激1995, ID: 10518
# Movie: 血衛, ID: 10469
# Movie: 女鬼橋, ID: 10437
# Movie: 音速小子, ID: 9246
# Movie: 紅鞋公主與七矮人, ID: 10417
# Movie: 1917, ID: 10189
# Movie: 肥龍過江, ID: 10449
# Movie: 杜立德, ID: 10316
# Movie: 變身特務, ID: 9008
# Movie: 巧虎電影：英雄遊樂園, ID: 10429
# Movie: 冰雪奇緣2, ID: 9597
# Movie: 鬼船瑪麗號, ID: 10265
# Movie: AI終結戰, ID: 10057
# Movie: 鎖命危機, ID: 9251
# Movie: 情書, ID: 6451
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026
# Movie: 秒速5公分, ID: 2305

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10836

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}
#/movietime_result.html?movie_id=10836&area_id=28
# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# [{'area_id': 28, 'title': '台北市', 'priority': 150, 'ts_update': 1547519309}, {'area_id': 8, 'title': '新北市', 'priority': 145, 'ts_update': 1547194527}, {'area_id': 16, 'title': '桃園', 'priority': 140, 'ts_update': 1547452573}, {'area_id': 20, 'title': '新竹', 'priority': 135, 'ts_update': 1547452603}, {'area_id': 2, 'title': '台中', 'priority': 125, 'ts_update': 1547507368}, {'area_id': 10, 'title': '台南', 'priority': 100, 'ts_update': 1547507403}, {'area_id': 17, 'title': '高雄', 'priority': 95, 'ts_update': 1547507403}]
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})
# 列印播放日期
#print(movie_date)
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 八月 4
# 八月 5
# 八月 6
# 八月 7
# 八月 8

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-08-04"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
# Out:
# <div class="pc-movie-schedule-form">
#     <div class="area_timebox">
#    <div class="area_title">台北市</div>
#       <ul id="theater_id_29" class="area_time _c jq_area_time" data-theater_name="國賓影城(台北長春廣場)" data-theater_url="http://www.ambassador.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=29" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=29">國賓影城(台北長春廣場)</a>
#            <span>02-25155755</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="73899404" class="gabtn"
#                         value="2020-08-04 13:30:00" data-movie_type="數位"
#                         data-movie_title="魔鬼剋星2(1989)"
#                         data-movie_date="08.04"
#                         data-movie_time="13:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '魔鬼剋星2(1989)']" data-news="news"
#                         />
#                     <label for="73899404" class="">13:30</label>
#                                                                     <input type="radio" name="schedule_list" id="73899405" class="gabtn"
#                         value="2020-08-04 18:10:00" data-movie_type="數位"
#                         data-movie_title="魔鬼剋星2(1989)"
#                         data-movie_date="08.04"
#                         data-movie_time="18:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '魔鬼剋星2(1989)']" data-news="news"
#                         />
#                     <label for="73899405" class="select">18:10</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_30" class="area_time _c jq_area_time" data-theater_name="欣欣秀泰影城" data-theater_url="http://www.showtimes.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=30" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id

#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '魔鬼剋星2(1989)']" data-ezding="ezding"
#                         />
#                     <label for="73875047" class="select">16:55</label>
#                                                                                     <input type="radio" name="schedule_list" id="73875048" class="gabtn"
#                         value="2020-08-04 21:20:00"  data-movie="1f77fe2c46ef44c5afae02c7c7e4771c"
#                         data-cinema="40288eb0050f542401050f554e7e0674" data-session="97ad95cb7f3a4d1c9f7963a9e71f3347"
#                         data-date="1596470400" data-time="1596547200"
#                         data-movie_type="數位"
#                         data-movie_title="魔鬼剋星2(1989)"
#                         data-movie_date="08.04"
#                         data-movie_time="21:20"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '魔鬼剋星2(1989)']" data-ezding="ezding"
#                         />
#                     <label for="73875048" class="select">21:20</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_186" class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_url="http://www.centuryasia.com.tw/default.aspx" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">喜樂時代影城南港店</a>
#            <span>02-27888185</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73877448" class="gabtn"
#                         value="2020-08-04 17:20:00"  data-movie="0fcc91964c7240a99fa024b49de01159"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="1d2bd65ccbba427dbfde295fda3dc2c1"
#                         data-date="1596470400" data-time="1596532800"
#                         data-movie_type="數位"
#                         data-movie_title="魔鬼剋星2(1989)"
#                         data-movie_date="08.04"
#                         data-movie_time="17:20"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '魔鬼剋星2(1989)']" data-ezding="ezding"
#                         />
#                     <label for="73877448" class="select">17:20</label>
#                                                                                     <input type="radio" name="schedule_list" id="73877449" class="gabtn"
#                         value="2020-08-04 21:45:00"  data-movie="0fcc91964c7240a99fa024b49de01159"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="d5e39c78430149f6b89b6e7b006533a9"
#                         data-date="1596470400" data-time="1596548700"
#                         data-movie_type="數位"
#                         data-movie_title="魔鬼剋星2(1989)"
#                         data-movie_date="08.04"
#                         data-movie_time="21:45"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '魔鬼剋星2(1989)']" data-ezding="ezding"
#                         />
#                     <label for="73877449" class="select">21:45</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_254" class="area_time _c jq_area_time" data-theater_name="MUVIE CINEMAS台北松仁威秀" data-theater_url="https://www.vscinemas.com.tw/vsweb/theater/detail2.aspx?id=23" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=254" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=254">MUVIE CINEMAS台北松仁威秀</a>
#            <span>(02)8780-0800</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73874395" class="gabtn"
#                         value="2020-08-04 19:25:00"  data-movie="28af0d803c234e42989213252796a67e"
#                         data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-session="e1d9b03727e64064ab68d4429844c3df"
#                         data-date="1596470400" data-time="1596540300"
#                         data-movie_type="數位"
#                         data-movie_title="魔鬼剋星2(1989)"
#                         data-movie_date="08.04"
#                         data-movie_time="19:25"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '魔鬼剋星2(1989)']" data-ezding="ezding"
#                         />
#                     <label for="73874395" class="select">19:25</label>
#                                                </div>
#            </li>
#           </ul>
#    </div>
#
#     <div class="booking_modal jq_booking_modal">
#     <div class="booking_modal_backdrop"></div>
#     <!-- 時報訂票 ＆ 有官網訂票 新增 class => no_seats -->
#     <div class="booking_modal_content jq_booking_modal_content">
#         <form method="get" action="https://movies.yahoo.com.tw/ticket/ezding_ticket" target="_blank" id="form_schedule">
#                 <div class="ezding_ticket_value">
#             <input type="hidden" name="movie_id" value="">
#             <input type="hidden" name="cinema_id" value="">
#             <input type="hidden" name="session_id" value="">
#             <input type="hidden" name="date" value="">
#             <input type="hidden" name="time" value="">
#             <input type="hidden" name="campaign_code" value="yahoopc">
#         </div>
#         <ul class="top_infos">
#             <li>
#                 <p>片名</p>
#                 <h3 id="top_infos_movie"></h3>
#             </li>
#             <li>
#                 <p>影城</p>
#                 <h3 id="top_infos_theater"></h3>
#             </li>
#             <li>
#                 <p>日期</p>
#                 <h3 id="top_infos_date"></h3>
#             </li>
#             <li>
#                 <p>版本</p>
#                 <h3 id="top_infos_movie_type"></h3>
#             </li>
#             <li>
#                 <p>時間</p>
#                 <h3 id="top_infos_time"></h3>
#             </li>
#         </ul>
#
#         <div class="booking_seats">
#             <a href="#" class="theater_schedules gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_全部電影場次', '']">全部電影場次</a>
#             <a href="#" class="theater_url gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_官網訂票', '']" target="_blank">官網訂票</a>
#             <p id="no_theater_url" class="no_theater_url">無提供官網訂票</p>
#
#             <p id="booking_number" class="booking_number">人數</p>
#             <div class="booking_seat_group jq_booking_seat_group">
#                                     <input type="radio" name="tickets" id="seat_1" value="1" />
#                     <label for="seat_1">1</label>
#                                     <input type="radio" name="tickets" id="seat_2" value="2"  checked />
#                     <label for="seat_2">2</label>
#                                     <input type="radio" name="tickets" id="seat_3" value="3" />
#                     <label for="seat_3">3</label>
#                                     <input type="radio" name="tickets" id="seat_4" value="4" />
#                     <label for="seat_4">4</label>
#                                     <input type="radio" name="tickets" id="seat_5" value="5" />
#                     <label for="seat_5">5</label>
#                                     <input type="radio" name="tickets" id="seat_6" value="6" />
#                     <label for="seat_6">6</label>
#                             </div>
#             <button type="submit" class="action_btn action_booking_btn jq_booking_btn gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_選位', '']">選位</button>
#             <a href="#" class="action_btn action_link jq_booking_link gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_時報戲院_官網選位', '']" target="_blank">官網訂票</a>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#         </form>
#
#         <!-- 無官網訂票區塊 -->
#         <div class="no_theater_section">
#             <p>無提供官網訂票</p>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#     </div>
# </div></div>

# %%
'''

  試著從上一步驟回傳的電影院資料中，擷取電影院名稱、影片放映類型以及時間表
  
  Your code here.

'''
for h in html:
    print('-'*20)
    print('電影院名稱:',h['data-theater_name'])
    print('影片放映類:',h.find("li",class_='taps').span.string)
    time= h.find_all("input",class_='gabtn')
    for t in time:
        print(t['value'])
# Out:
# --------------------
# 電影院名稱: 國賓影城(台北長春廣場)
# 影片放映類: 數位
# 2020-08-04 13:30:00
# 2020-08-04 18:10:00
# --------------------
# 電影院名稱: 欣欣秀泰影城
# 影片放映類: 數位
# 2020-08-04 19:30:00
# --------------------
# 電影院名稱: 台北美麗華大直影城
# 影片放映類: 數位
# 2020-08-04 13:50:00
# 2020-08-04 21:00:00
# --------------------
# 電影院名稱: 台北in89豪華數位影城
# 影片放映類: 數位
# 2020-08-04 19:45:00
# --------------------
# 電影院名稱: 台北信義威秀影城
# 影片放映類: 數位
# 2020-08-04 16:55:00
# 2020-08-04 21:20:00
# --------------------
# 電影院名稱: 喜樂時代影城南港店
# 影片放映類: 數位
# 2020-08-04 17:20:00
# 2020-08-04 21:45:00
# --------------------
# 電影院名稱: MUVIE CINEMAS台北松仁威秀
# 影片放映類: 數位
# 2020-08-04 19:25:00
